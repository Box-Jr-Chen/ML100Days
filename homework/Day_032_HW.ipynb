# %% [markdown]
# ## 作業:
# 作業目標，讓大家熟悉連續型分配的語法，
# 以及怎麼透過 python 語法進行常態分配的機率運算。

# %% [markdown]
# ### Q1:計算標準常態分配，小於1的機率有多大?
# ![](Q1.png)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics

# %%
## Q1
#  提示: 用 cdf 來算



mu=0
sigma=1
b=  stats.norm.cdf(1,mu, sigma)
print("P(Z<1)=",b)
# Out:
# P(Z<1)= 0.8413447460685429

# %% [markdown]
# ### Q2:計算標準常態分配，大於1，小於 -1 的機率有多大?
# ![](Q2.png)

# %%
## Q2

mu=0
sigma=1
b=  stats.norm.cdf(1,mu, sigma)
a=  stats.norm.cdf(-1,mu, sigma)

answer =1-(b-a)
print("P(Z>1 or Z<-1)=",answer)
# Out:
# P(Z>1 or Z<-1)= 0.31731050786291415

# %% [markdown]
# ### Q3:X~N(2,4),x 服從常態分配，平均數為2,變異數為 4，計算 X小於 6 的機率有多大?

# %%
## Q3
#  提示: 和 Q1,Q2 不同，要先標準化。



cumsum_probs =  stats.norm.cdf(6, loc = 2, scale = 2)
cumsum_probs

plt.ylabel('P(X<=6)')
plt.xlabel('x')
plt.title(' cdf of Nomal(2,2)')
plt.plot(6, cumsum_probs,"b-", linewidth=2)
plt.show()
