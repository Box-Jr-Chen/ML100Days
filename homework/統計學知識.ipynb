# %% [markdown]
# ### PDF、CDF :
#
# ![image](CDF_PDF.jpg)

# %% [markdown]
# ### 1. CDF 微分就是 PDF
#
# <img align="left" width="200"  src="PDF特性_1.jpg">

# %% [markdown]
# ### 2. PDF 積分就是 CDF
#
# <img align="left" width="200" src="PDF特性_2.jpg">

# %% [markdown]
# ### 3. 落在a跟b之間
#
# <img align="left" width="200" src="PDF特性_3.jpg">

# %% [markdown]
# ### 4. 如果a、b是無窮大 最大就是 1
#
# <img align="left" width="200" src="PDF特性_4.jpg">

# %% [markdown]
# ### 5. 機率密度函數必須大於0
#     (在極小區間內的值是可以大於1)
#
#  <img align="left" width="200" src="PDF特性_5.jpg">

# %% [markdown]
# ## 離散型分配 :
#
#     - 離散均勻分配( Discrete Uniform Distribution )
#
#     - 伯努利分配( Bernoulli Distribution )
#
#     - 二項分配(Binomial Distribution)
#
#     - 負二項分配(Negative Binomial Distribution)
#
#     - 超幾何分配(Hypergeometric Distribution)

# %%
- 離散均勻分配( Discrete Uniform Distribution )

# %% [markdown]
# ## 連續分配 :

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics

# %%
# 連續型均勻分配 : 無法列出所有實驗的可能值（不可數）

low=1
high=5
x=np.linspace(0, 10, 50)
# 2. 產生 pdf
y = stats.uniform.pdf(x,low, high-low)
plt.plot(x, y, "b-", linewidth=2)
plt.grid(True)
plt.title('pdf of uniform(1,5)')
plt.show()

# %%
# 2. 產生 pdf
y = stats.uniform.cdf(x,low, high-low)
plt.plot(x, y, "b-", linewidth=2)
plt.grid(True)
plt.title('pdf of uniform(1,5)')
plt.show()

# %%
# 常態分配
