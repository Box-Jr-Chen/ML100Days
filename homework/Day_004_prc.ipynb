# %%
# 載入 NumPy 套件
import numpy as np

# %%
a = np.array( [20,30,40,50] )

# %%
a
# Out:
# array([20, 30, 40, 50])

# %%
a_t = a.reshape(4,1)

# %%
a_t
# Out:
# array([[20],
#        [30],
#        [40],
#        [50]])

# %%
a + a_t
# Out:
# array([[ 40,  50,  60,  70],
#        [ 50,  60,  70,  80],
#        [ 60,  70,  80,  90],
#        [ 70,  80,  90, 100]])

# %%
a * a_t
# Out:
# array([[ 400,  600,  800, 1000],
#        [ 600,  900, 1200, 1500],
#        [ 800, 1200, 1600, 2000],
#        [1000, 1500, 2000, 2500]])

# %%
np.power(a_t,2)
# Out:
# array([[ 400],
#        [ 900],
#        [1600],
#        [2500]], dtype=int32)

# %%
np.sqrt(a_t)
# Out:
# array([[4.47213595],
#        [5.47722558],
#        [6.32455532],
#        [7.07106781]])

# %%
np.e
# Out:
# 2.718281828459045

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
np.exp(np.arange(5))
# Out:
# array([ 1.        ,  2.71828183,  7.3890561 , 20.08553692, 54.59815003])

# %%
np.log2(16)
# Out:
# 4.0

# %%
np.log2([16,8,5])
# Out:
# array([4.        , 3.        , 2.32192809])

# %%
np.log2([-1,1,2])
# Out:
# <ipython-input-77-81a4b9e56b61>:1: RuntimeWarning: invalid value encountered in log2
#   np.log2([-1,1,2])
# array([nan,  0.,  1.])
