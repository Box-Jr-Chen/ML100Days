# %% [markdown]
# # 作業: 處理分類數據
#
# 1.建立簡單的水果資料集 fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'] counts = [5, 3, 4, 2, 4, 6]
#
# 2.利用vbar 水果名稱因子列表作為x 坐標，將條形高度作為top坐標，以及可選地width我們想要設置的任何屬性進行調用：
#
# p.vbar(x=fruits, top=[5, 3, 4, 2, 4, 6], width=0.9)
#
# 由於Bokeh會按順序顯示條形，因此在條形圖中“排序”條形與對范圍的因子進行排序相同。
#
# sorted_fruits = sorted(fruits, key=lambda x: counts[fruits.index(x)])

# %%
import bokeh.io
from bokeh.resources import INLINE
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.sampledata.stocks import AAPL, GOOG, IBM, MSFT
import pandas as pd

# 環境 settings
bokeh.io.reset_output()
bokeh.io.output_notebook(INLINE)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-cddc2270486b> in <module>
#       2 from bokeh.resources import INLINE
#       3 from bokeh.plotting import figure, output_file, show, output_notebook
# ----> 4 from bokeh.sampledata.stocks import AAPL, GOOG, IBM, MSFT
#       5 import pandas as pd
#       6
#
# ~\.conda\envs\tf_base\lib\site-packages\bokeh\sampledata\stocks.py in <module>
#      96 #-----------------------------------------------------------------------------
#      97
# ---> 98 AAPL = _read_data('AAPL')
#      99 FB   = _read_data('FB')
#     100 GOOG = _read_data('GOOG')
#
# ~\.conda\envs\tf_base\lib\site-packages\bokeh\sampledata\stocks.py in _read_data(name)
#      68
#      69     '''
# ---> 70     filename = external_path(name+'.csv')
#      71     data = {
#      72         'date' : [],
#
# ~\.conda\envs\tf_base\lib\site-packages\bokeh\util\sampledata.py in external_path(filename)
#     121
#     122 def external_path(filename: str) -> str:
# --> 123     data_dir = external_data_dir()
#     124     fn = join(data_dir, filename)
#     125     if not exists(fn) and isfile(fn):
#
# ~\.conda\envs\tf_base\lib\site-packages\bokeh\util\sampledata.py in external_data_dir(create)
#     108     if not exists(data_dir):
#     109         if not create:
# --> 110             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#     111         print("Creating %s directory" % data_dir)
#     112         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()
