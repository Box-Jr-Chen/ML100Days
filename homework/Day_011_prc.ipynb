# %%
import pandas as pd

df = pd.DataFrame({
    'col1': [1, 1, 3, 5],
    'col2': [2, 1, 9, 8],
})

# %%
df
# Out:
#    col1  col2
# 0     1     2
# 1     1     1
# 2     3     9
# 3     5     8

# %%
df.sort_values(by=['col1'])
# Out:
#       col1  col2
# 3  test_21     8
# 1  test_22     1
# 0  test_25     2
# 2  test_29     9

# %%
df.sort_values(by=['col1', 'col2'])
# Out:
#       col1  col2
# 3  test_21     8
# 1  test_22     1
# 0  test_25     2
# 2  test_29     9

# %%
df.sort_values(by='col1', ascending=False)
# Out:
#       col1  col2
# 2  test_29     9
# 0  test_25     2
# 1  test_22     1
# 3  test_21     8

# %%
df.count()
# Out:
# col1    4
# col2    4
# dtype: int64

# %%
df.min()
# Out:
# col1    test_21
# col2          1
# dtype: object

# %%
df.max()
# Out:
# col1    test_29
# col2          9
# dtype: object

# %%
df.var()
# Out:
# col2    16.666667
# dtype: float64

# %%
df.std()
# Out:
# col2    4.082483
# dtype: float64

# %%
df.median()
# Out:
# col1    2.0
# col2    5.0
# dtype: float64

# %%
df.quantile(0.75)
# Out:
# col1    3.50
# col2    8.25
# Name: 0.75, dtype: float64

# %%
df.min()
# Out:
# col1    1
# col2    1
# dtype: int64

# %%
df.max()
# Out:
# col1    5
# col2    9
# dtype: int64

# %%
df.std()
# Out:
# col1    1.914854
# col2    4.082483
# dtype: float64

# %%
df.corr()
# Out:
#           col1      col2
# col1  1.000000  0.852803
# col2  0.852803  1.000000
