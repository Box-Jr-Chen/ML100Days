# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
m = Basemap(projection='mill',
           llcrnrlat=-40,
           llcrnrlon=-40,
           urcrnrlat=50,
           urcrnrlon=75)
m.drawcoastlines()
plt.show()
